# %% [markdown]
#  ***bir boş liste var bana belli bir aralıkta değer vericek ve bu değeri listeye ekleyecek ve listenin boyutu 10 eleman olunca fonksiyon duracak ve listedeki çift değerleri ayrı bir listeye ekleyecek ve listede aynı degerden birden fazla olan degerleri ayrı bir list icinde tutacak***

# %%
from random import randint
liste1 = []
liste2 = []
liste3 = []
while len(liste1) < 10:

  deger = randint(1,5)
  liste1.append(deger)
  if deger % 2 == 0 :
    liste2.append(deger)
  if liste1.count(deger)>1 in liste1:
    liste3.append(deger)
print(f"Liste: {liste1}")
print(f"Listedeki çift sayıları tutan liste: {liste2}")
print(f"Listedeki tekrar eden sayılar: {liste3}")
# Out:
# Liste: [4, 3, 2, 2, 2, 1, 3, 1, 4, 3]
# Listedeki çift sayıları tutan liste: [4, 2, 2, 2, 4]
# Listedeki tekrar eden sayılar: [3, 1, 4, 3]
